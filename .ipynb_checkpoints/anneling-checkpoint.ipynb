# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import anneling_process as ap
import plot_functions as fpl

r42 = np.random.RandomState(42)

# %%
N = 100
T_init = 10
T_end = 0.0001

init_state = np.random.permutation(N)
cities_coord = r42.rand(2,N)*10

E_hist, T_hist, final_state = ap.SimulatedAnnealing(cities_coord, T_init, T_end)

# %%
fpl.plot_hist(E_hist, T_hist)

# %%
fpl.plot_graph(cities_coord,init_state)

# %%
fpl.plot_graph(cities_coord,final_state)
